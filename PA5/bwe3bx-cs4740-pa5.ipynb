# %%
bucket = 'bwe3bx-sagemaker'
prefix = 'sagemaker/xgboost_credit_risk'

# Define IAM role
import boto3
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sagemaker
from sagemaker import get_execution_role
from sagemaker.inputs import TrainingInput
from sagemaker.serializers import CSVSerializer

role = get_execution_role()

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00350/default%20of%20credit%20card%20clients.xls
# Out:
# --2021-04-14 15:41:35--  https://archive.ics.uci.edu/ml/machine-learning-databases/00350/default%20of%20credit%20card%20clients.xls
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5539328 (5.3M) [application/x-httpd-php]
# Saving to: ‘default of credit card clients.xls’
#
# default of credit c 100%[===================>]   5.28M  8.70MB/s    in 0.6s
#
# 2021-04-14 15:41:36 (8.70 MB/s) - ‘default of credit card clients.xls’ saved [5539328/5539328]

# %%
dataset = pd.read_excel('default of credit card clients.xls')
pd.set_option('display.max_rows', 8)
pd.set_option('display.max_columns', 15)
dataset
# Out:
#       Unnamed: 0         X1   X2         X3        X4   X5     X6  ...  \
# 0             ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  ...
# 1              1      20000    2          2         1   24      2  ...
# 2              2     120000    2          2         2   26     -1  ...
# 3              3      90000    2          2         2   34      0  ...
# ...          ...        ...  ...        ...       ...  ...    ...  ...
# 29997      29997     150000    1          3         2   43     -1  ...
# 29998      29998      30000    1          2         2   37      4  ...
# 29999      29999      80000    1          3         1   41      1  ...
# 30000      30000      50000    1          2         1   46      0  ...
#
#             X18       X19       X20       X21       X22       X23  \
# 0      PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 1             0       689         0         0         0         0
# 2             0      1000      1000      1000         0      2000
# 3          1518      1500      1000      1000      1000      5000
# ...         ...       ...       ...       ...       ...       ...
# 29997      1837      3526      8998       129         0         0
# 29998         0         0     22000      4200      2000      3100
# 29999     85900      3409      1178      1926     52964      1804
# 30000      2078      1800      1430      1000      1000      1000
#
#                                 Y
# 0      default payment next month
# 1                               1
# 2                               1
# 3                               0
# ...                           ...
# 29997                           0
# 29998                           1
# 29999                           1
# 30000                           1
#
# [30001 rows x 25 columns]

# %%
dataset = dataset.drop('Unnamed: 0', axis=1)
dataset = pd.concat([dataset['Y'], dataset.drop(['Y'], axis=1)], axis=1)

# %%
train_data, validation_data, test_data = np.split(dataset.sample(frac=1, random_state=1729), [int(0.7 * len(dataset)), int(0.9 * len(dataset))])
train_data.to_csv('train.csv', header=False, index=False)
validation_data.to_csv('validation.csv', header=False, index=False)

# %%
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'validation/validation.csv')).upload_file('validation.csv')
s3_input_train = TrainingInput(s3_data='s3://{}/{}/train'.format(bucket, prefix), content_type='csv')
s3_input_validation = TrainingInput(s3_data='s3://{}/{}/validation/'.format(bucket, prefix), content_type='csv')

# %%
containers = {'us-west-2': '433757028032.dkr.ecr.us-west-2.amazonaws.com/xgboost:latest',
              'us-east-1': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
              'us-east-2': '825641698319.dkr.ecr.us-east-2.amazonaws.com/xgboost:latest',
              'eu-west-1': '685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:latest'}

sess = sagemaker.Session()
xgb = sagemaker.estimator.Estimator(containers[boto3.Session().region_name],
                                    role, 
                                    instance_count=1, 
                                    instance_type='ml.m4.xlarge',
                                    output_path='s3://{}/{}/output'.format(bucket, prefix),
                                    sagemaker_session=sess)
xgb.set_hyperparameters(eta=0.1, objective='binary:logistic', num_round=25) 
xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2021-04-14 15:48:55 Starting - Starting the training job...
# 2021-04-14 15:49:18 Starting - Launching requested ML instancesProfilerReport-1618415335: InProgress
# .........
# 2021-04-14 15:50:39 Starting - Preparing the instances for training......
# 2021-04-14 15:51:48 Downloading - Downloading input data...
# 2021-04-14 15:52:19 Training - Downloading the training image..Arguments: train
# [2021-04-14:15:52:37:INFO] Running standalone xgboost training.
# [2021-04-14:15:52:37:INFO] File size need to be processed in the node: 2.32mb. Available memory size in the node: 8415.96mb
# [2021-04-14:15:52:37:INFO] Determined delimiter of CSV input is ','
# [15:52:37] S3DistributionType set as FullyReplicated
# [15:52:37] 21000x23 matrix with 483000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2021-04-14:15:52:37:INFO] Determined delimiter of CSV input is ','
# [15:52:37] S3DistributionType set as FullyReplicated
# [15:52:37] 6000x23 matrix with 138000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [15:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [0]#011train-error:0.173619#011validation-error:0.181
# [15:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [1]#011train-error:0.173143#011validation-error:0.176667
# [15:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [2]#011train-error:0.172857#011validation-error:0.176167
# [15:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [3]#011train-error:0.17119#011validation-error:0.176333
# [15:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [4]#011train-error:0.170143#011validation-error:0.175667
# [15:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [5]#011train-error:0.169381#011validation-error:0.176833
# [15:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [6]#011train-error:0.169#011validation-error:0.176667
# [15:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [7]#011train-error:0.168619#011validation-error:0.177167
# [15:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [8]#011train-error:0.168286#011validation-error:0.177333
# [15:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=6
# [9]#011train-error:0.168095#011validation-error:0.176167
# [15:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=6
# [10]#011train-error:0.168143#011validation-error:0.177833
# [15:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [11]#011train-error:0.16781#011validation-error:0.177833
# [15:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=6
# [12]#011train-error:0.167#011validation-error:0.178667
# [15:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [13]#011train-error:0.166667#011validation-error:0.177167
# [15:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [14]#011train-error:0.166095#011validation-error:0.177667
# [15:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [15]#011train-error:0.16581#011validation-error:0.177833
# [15:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [16]#011train-error:0.165714#011validation-error:0.178667
# [15:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=6
# [17]#011train-error:0.164571#011validation-error:0.178333
# [15:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=6
# [18]#011train-error:0.164476#011validation-error:0.179167
# [15:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [19]#011train-error:0.164#011validation-error:0.179667
# [15:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=6
# [20]#011train-error:0.163238#011validation-error:0.1795
# [15:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [21]#011train-error:0.163286#011validation-error:0.179833
# [15:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [22]#011train-error:0.162571#011validation-error:0.179333
# [15:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [23]#011train-error:0.16219#011validation-error:0.178333
# [15:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [24]#011train-error:0.161762#011validation-error:0.178833
#
# 2021-04-14 15:52:39 Training - Training image download completed. Training in progress.
# 2021-04-14 15:53:27 Uploading - Uploading generated training model
# 2021-04-14 15:53:27 Completed - Training job completed
# Training seconds: 99
# Billable seconds: 99

# %%
xgb_predictor = xgb.deploy(
	initial_instance_count = 1,
	instance_type = 'ml.m4.xlarge',
	serializer = CSVSerializer())
# Out:
# ---------------!

# %%
def predict(data, rows=500):
    split_array = np.array_split(data, int(data.shape[0] / float(rows) + 1))
    predictions = ''
    for array in split_array:
        predictions = ','.join([predictions, xgb_predictor.predict(array).decode('utf-8')])

    return np.fromstring(predictions[1:], sep=',')

predictions = predict(test_data.to_numpy()[:,1:])
predictions
# Out:
# array([0.10145303, 0.29316297, 0.70782304, ..., 0.15233986, 0.38610485,
#        0.10773233])

# %%
xgb.set_hyperparameters(max_depth=5,eta=0.2,gamma=4,min_child_weight=6,subsample=0.8,silent=0,objective='binary:logistic',num_round=100)

# %%
xgb.fit({'train': s3_input_train})
# Out:
# 2021-04-14 16:09:50 Starting - Starting the training job...
# 2021-04-14 16:10:14 Starting - Launching requested ML instancesProfilerReport-1618416590: InProgress
# ......
# 2021-04-14 16:11:14 Starting - Preparing the instances for training.........
# 2021-04-14 16:12:34 Downloading - Downloading input data...
# 2021-04-14 16:13:14 Training - Downloading the training image..Arguments: train
# [2021-04-14:16:13:28:INFO] Running standalone xgboost training.
# [2021-04-14:16:13:28:INFO] Path /opt/ml/input/data/validation does not exist!
# [2021-04-14:16:13:28:INFO] File size need to be processed in the node: 1.8mb. Available memory size in the node: 8401.9mb
# [2021-04-14:16:13:28:INFO] Determined delimiter of CSV input is ','
# [16:13:28] S3DistributionType set as FullyReplicated
# [16:13:28] 21000x23 matrix with 483000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 2 pruned nodes, max_depth=5
# [0]#011train-error:0.177476
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 4 pruned nodes, max_depth=5
# [1]#011train-error:0.176905
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=5
# [2]#011train-error:0.176143
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 2 pruned nodes, max_depth=5
# [3]#011train-error:0.175286
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 10 pruned nodes, max_depth=5
# [4]#011train-error:0.175143
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 6 pruned nodes, max_depth=5
# [5]#011train-error:0.17419
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 6 pruned nodes, max_depth=5
# [6]#011train-error:0.17419
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 2 pruned nodes, max_depth=5
# [7]#011train-error:0.174
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [8]#011train-error:0.173333
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 4 pruned nodes, max_depth=5
# [9]#011train-error:0.173048
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 6 pruned nodes, max_depth=5
# [10]#011train-error:0.172714
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 8 pruned nodes, max_depth=5
# [11]#011train-error:0.172429
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 10 pruned nodes, max_depth=5
# [12]#011train-error:0.172095
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=5
# [13]#011train-error:0.172476
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 4 pruned nodes, max_depth=5
# [14]#011train-error:0.172095
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 8 pruned nodes, max_depth=5
# [15]#011train-error:0.171333
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 14 pruned nodes, max_depth=5
# [16]#011train-error:0.171095
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 2 pruned nodes, max_depth=5
# [17]#011train-error:0.170381
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 4 pruned nodes, max_depth=5
# [18]#011train-error:0.170905
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=5
# [19]#011train-error:0.170429
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 16 pruned nodes, max_depth=5
# [20]#011train-error:0.17019
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 14 pruned nodes, max_depth=5
# [21]#011train-error:0.169857
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=5
# [22]#011train-error:0.169714
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 10 pruned nodes, max_depth=5
# [23]#011train-error:0.169333
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=5
# [24]#011train-error:0.169571
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [25]#011train-error:0.169857
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 6 pruned nodes, max_depth=5
# [26]#011train-error:0.169476
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 10 pruned nodes, max_depth=5
# [27]#011train-error:0.169381
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [28]#011train-error:0.169286
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=5
# [29]#011train-error:0.168762
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 10 pruned nodes, max_depth=5
# [30]#011train-error:0.168429
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [31]#011train-error:0.168524
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [32]#011train-error:0.168429
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 6 pruned nodes, max_depth=5
# [33]#011train-error:0.168524
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=5
# [34]#011train-error:0.168476
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [35]#011train-error:0.167762
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 6 pruned nodes, max_depth=5
# [36]#011train-error:0.167905
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2 pruned nodes, max_depth=5
# [37]#011train-error:0.167619
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [38]#011train-error:0.166857
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 6 pruned nodes, max_depth=5
# [39]#011train-error:0.166857
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=5
# [40]#011train-error:0.166952
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 4 pruned nodes, max_depth=5
# [41]#011train-error:0.166714
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [42]#011train-error:0.166571
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 8 pruned nodes, max_depth=5
# [43]#011train-error:0.166762
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 4 pruned nodes, max_depth=5
# [44]#011train-error:0.167
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 10 pruned nodes, max_depth=5
# [45]#011train-error:0.166
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 8 pruned nodes, max_depth=5
# [46]#011train-error:0.165476
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=5
# [47]#011train-error:0.165619
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [48]#011train-error:0.165333
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [49]#011train-error:0.165143
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 14 pruned nodes, max_depth=5
# [50]#011train-error:0.164952
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [51]#011train-error:0.164381
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [52]#011train-error:0.164381
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 6 pruned nodes, max_depth=5
# [53]#011train-error:0.163762
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 4 pruned nodes, max_depth=5
# [54]#011train-error:0.163762
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=5
# [55]#011train-error:0.163238
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [56]#011train-error:0.163286
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 12 pruned nodes, max_depth=5
# [57]#011train-error:0.16319
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 6 pruned nodes, max_depth=5
# [58]#011train-error:0.162952
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [59]#011train-error:0.16319
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [60]#011train-error:0.162857
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 6 pruned nodes, max_depth=5
# [61]#011train-error:0.162905
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 6 pruned nodes, max_depth=5
# [62]#011train-error:0.162619
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [63]#011train-error:0.162667
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 18 pruned nodes, max_depth=5
# [64]#011train-error:0.162619
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 12 pruned nodes, max_depth=4
# [65]#011train-error:0.162429
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 26 pruned nodes, max_depth=4
# [66]#011train-error:0.162333
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 14 pruned nodes, max_depth=5
# [67]#011train-error:0.161857
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=4
# [68]#011train-error:0.161524
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 16 pruned nodes, max_depth=4
# [69]#011train-error:0.161667
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 10 pruned nodes, max_depth=5
# [70]#011train-error:0.16119
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 16 pruned nodes, max_depth=5
# [71]#011train-error:0.16119
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=5
# [72]#011train-error:0.161381
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [73]#011train-error:0.161286
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 4 pruned nodes, max_depth=5
# [74]#011train-error:0.161429
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [75]#011train-error:0.161238
# [16:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=4
# [76]#011train-error:0.161143
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [77]#011train-error:0.161048
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [78]#011train-error:0.161048
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 2 pruned nodes, max_depth=5
# [79]#011train-error:0.160714
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 12 pruned nodes, max_depth=5
# [80]#011train-error:0.160429
# [81]#011train-error:0.159857
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 20 pruned nodes, max_depth=5
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=5
# [82]#011train-error:0.159952
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 4 pruned nodes, max_depth=5
# [83]#011train-error:0.15919
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [84]#011train-error:0.158762
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 4 pruned nodes, max_depth=5
# [85]#011train-error:0.15881
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [86]#011train-error:0.158952
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [87]#011train-error:0.158762
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 14 pruned nodes, max_depth=3
# [88]#011train-error:0.15881
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [89]#011train-error:0.158714
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 16 pruned nodes, max_depth=5
# [90]#011train-error:0.158714
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 16 pruned nodes, max_depth=5
# [91]#011train-error:0.158619
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 8 pruned nodes, max_depth=5
# [92]#011train-error:0.157905
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2 pruned nodes, max_depth=5
# [93]#011train-error:0.157714
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=5
# [94]#011train-error:0.157238
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [95]#011train-error:0.157333
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=5
# [96]#011train-error:0.157429
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 12 pruned nodes, max_depth=5
# [97]#011train-error:0.157095
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [98]#011train-error:0.156857
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 8 pruned nodes, max_depth=5
# [99]#011train-error:0.156762
#
# 2021-04-14 16:13:41 Uploading - Uploading generated training model
# 2021-04-14 16:13:41 Completed - Training job completed
# Training seconds: 68
# Billable seconds: 68

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'y_yes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-e16b098d05e5> in <module>
# ----> 1 cm = pd.crosstab(index=test_data['y_yes'], columns=np.round(predictions_array), rownames=['Observed'], colnames=['Predicted'])
#       2 tn = cm.iloc[0,0]; fn = cm.iloc[1,0]; tp = cm.iloc[1,1]; fp = cm.iloc[0,1]; p = (tp+tn)/(tp+tn+fp+fn)*100
#       3 print("\n{0:<20}{1:<4.1f}%\n".format("Overall Classification Rate: ", p))
#       4 print("{0:<15}{1:<15}{2:>8}".format("Predicted", "No Purchase", "Purchase"))
#       5 print("Observed")
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'y_yes'

# %%
test_data_array = test_data.drop(['Y'], axis=1).values #load the data into an array
xgb_predictor.serializer = CSVSerializer() # set the serializer type
predictions = xgb_predictor.predict(test_data_array).decode('utf-8') # predict!
predictions_array = np.fromstring(predictions[1:], sep=',') # and turn the prediction into an array
print(predictions_array.shape)
# Out:
# (3001,)

# %%
cm = pd.crosstab(index=test_data['Y'], columns=np.round(predictions_array), rownames=['Observed'], colnames=['Predicted'])
tn = cm.iloc[0,0]; fn = cm.iloc[1,0]; tp = cm.iloc[1,1]; fp = cm.iloc[0,1]; p = (tp+tn)/(tp+tn+fp+fn)*100
print("\n{0:<20}{1:<4.1f}%\n".format("Overall Classification Rate: ", p))
print("{0:<15}{1:<15}{2:>8}".format("Predicted", "No Default", "Default"))
print("Observed")
print("{0:<15}{1:<2.0f}% ({2:<}){3:>6.0f}% ({4:<})".format("No Default", tn/(tn+fn)*100,tn, fp/(tp+fp)*100, fp))
print("{0:<16}{1:<1.0f}% ({2:<}){3:>7.0f}% ({4:<}) \n".format("Default", fn/(tn+fn)*100,fn, tp/(tp+fp)*100, tp))
# Out:
# Overall Classification Rate: 82.1%
#
# Predicted      No Default      Default
# Observed
# No Default     84% (2245)    33% (107)
# Default         16% (429)     67% (220)
